# %%
library(worldfootballR)
library(dplyr)
library(ggplot2)

# %%
injuries <- read.csv("/home/yahor/Documents/uni/sem_3/twd/football-injuries/data/Final-player.txt", header = TRUE, sep = "\t", stringsAsFactors = FALSE)

# %%
injuries
# Out:
#      X..u238223..uEderson..uManchester.City..u1.14.Bill...u20ac..u1993.08.17..u89..u1.88.xa0..uBrazil..uGoalkeeper..uleft....u.nBenfica...u.nMan.City...u17.18..uJul.1..2017....u.nRio.Ave.FC...u.nBenfica...u15.16..uJul.1..2015....u.nGD.Ribeir.xe3o...u.nRio.Ave.FC...u12.13..uJul.1..2012....u.nBenfica.U19...u.nGD.Ribeir.xe3o...u11.12..uJul.1..2011....u.nBenfica.U17...u.nBenfica.U19...u10.11..uJul.1..2010....u.nS.xe3o.Paulo.U17...u.nBenfica.U17...u09.10..uJan.1..2010......u16.17..uMeniscal.Injury..u29....
# ...
