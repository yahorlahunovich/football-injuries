# %%
library(worldfootballR)
library(dplyr)
library(ggplot2)

# %%
injuries <- read.csv("/home/yahor/Documents/uni/sem_3/twd/football-injuries/data/Final-player.csv")

# %%
head(injuries)
# Out:
#   X id     name             club            club_value   birth      weight
# 1 0 238223 Ederson          Manchester City 1,14 Bill. € 1993-08-17 89
# 2 1  40423 Claudio Bravo    Manchester City 1,14 Bill. € 1983-04-13 84
# 3 2 371021 Arijanet Murić   Manchester City 1,14 Bill. € 1998-11-07 -
# 4 3 186590 John Stones      Manchester City 1,14 Bill. € 1994-05-28 69
# 5 4 176553 Aymeric Laporte  Manchester City 1,14 Bill. € 1994-05-27 85
# 6 5  54781 Nicolás Otamendi Manchester City 1,14 Bill. € 1988-02-12 80
#   height country   role                   foot
# 1 1,88   Brazil    Goalkeeper             left
# 2 1,84   Chile     Goalkeeper             right
# 3 1,98   Kosovo    Goalkeeper             right
# 4 1,88   England   Defender - Centre-Back right
# 5 1,91   France    Defender - Centre-Back left
# 6 1,83   Argentina Defender - Centre-Back right
#   transfers
# ...
